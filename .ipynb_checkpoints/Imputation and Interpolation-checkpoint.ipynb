# %% [markdown]
# ## Library Imports

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Loading Dataset

# %%
dataset = pd.read_csv("dataset.csv", index_col=[0, 1]).transpose()
dataset
# Out:
# Discipline  Science & Technology Disciplines                                 \
# Year                                 Science  Engg. Medicine Agri. Vety.Sc.
# 1974-75                                106.2    1.3     21.0   0.3     0.08
# 1979-80                                140.1    4.4     24.4   1.1     0.20
# 1985-86                                215.7   12.2     37.5   2.3     0.60
# 1991-92                                302.0   18.3     51.1   3.6     0.90
# 1992-93                                318.6   19.2     53.8   3.8     1.00
# 1993-94                                334.4   20.0      NaN   NaN      NaN
# 1994-95                                415.0   24.9      NaN   NaN      NaN
# 1995-96                                440.4   26.4      NaN   NaN      NaN
# 1996-97                                462.9   27.6      NaN   NaN      NaN
# 1997-98                                469.6   51.3     80.7  14.7     2.40
# 1998-99                                494.2   54.1     84.9  15.4     2.60
# 1999-00                                520.9   63.1     90.5  15.5     2.70
# 2001-02                                699.4  131.8    123.0   9.1     3.20
# 2002-03                                736.9  154.0    134.4   9.3     3.00
# 2003-04                                809.0  165.3    145.3   9.9     3.00
# 2004-05                                850.2  175.7    153.7  10.6     3.40
# 2005-06                                901.3  185.9    162.6  10.8     3.60
#
# Discipline  Other Disciplines                                  Total
# Year                     Arts Commerce   Law Education Others*   Total
# 1974-75                 363.0     22.1   5.9      29.0     4.1   553.0
# 1979-80                 397.9     68.0  11.0      34.5     7.4   689.0
# 1985-86                 576.3    156.7  17.6      38.6     9.0  1067.5
# 1991-92                 824.9    212.0  24.9      58.1    15.1  1512.2
# 1992-93                 867.5    222.0  26.2      61.1    15.9  1590.3
# 1993-94                 905.1    235.3  30.0      65.1    74.1  1664.1
# 1994-95                1123.2    292.0  37.3      80.8    91.9  2065.0
# 1995-96                1191.8    309.8  39.6      85.7    97.6  2191.3
# 1996-97                1252.7    325.7  41.7      90.1   102.5  2303.2
# 1997-98                1330.5    332.6  48.9      83.2    31.8  2445.7
# 1998-99                1400.3    350.1  51.5      87.5    33.5  2574.0
# 1999-00                1489.5    381.4  54.8      87.6    35.6  2741.6
# 2001-02                1820.1    582.0  56.9      59.4    29.5  3514.4
# 2002-03                1889.8    608.9  61.9      67.1    30.6  3695.9
# 2003-04                2041.8    657.7  62.5      76.0    31.6  4002.1
# 2004-05                2162.4    696.5  68.6      78.7    34.3  4234.1
# 2005-06                2278.3    735.2  73.2      82.7    33.1  4466.7

# %% [markdown]
# ## Displaying NA Values (Missing Data)

# %%
dataset.iloc[5:9, 2:5]
# Out:
# Discipline  Science & Technology Disciplines
# Year                                Medicine Agri. Vety.Sc.
# 1993-94                                  NaN   NaN      NaN
# 1994-95                                  NaN   NaN      NaN
# 1995-96                                  NaN   NaN      NaN
# 1996-97                                  NaN   NaN      NaN

# %% [markdown]
# ## Imputations
# ### 1. Mean Imputation

# %%
# Mean Imputation
means = dataset.mean()
mean_imputed = dataset.fillna(means)

print(means)
mean_imputed.iloc[5:9, 2:5]
# Out:
# Discipline                        Year
# Science & Technology Disciplines  Science         483.341176
#                                   Engg.            66.794118
#                                   Medicine         89.453846
#                                   Agri.             8.184615
#                                   Vety.Sc.          2.052308
# Other Disciplines                 Arts           1289.123529
#                                   Commerce        364.000000
#                                   Law              41.911765
#                                   Education        68.541176
#                                   Others*          39.858824
# Total                             Total          2430.005882
# dtype: float64
# Discipline  Science & Technology Disciplines
# Year                                Medicine     Agri.  Vety.Sc.
# 1993-94                            89.453846  8.184615  2.052308
# 1994-95                            89.453846  8.184615  2.052308
# 1995-96                            89.453846  8.184615  2.052308
# 1996-97                            89.453846  8.184615  2.052308

# %% [markdown]
# ### 2. Hot Deck Imputation - filling prior value

# %%
hot_deck = dataset.fillna(method='ffill')
hot_deck.iloc[5:9, 2:5]
# Out:
# Discipline  Science & Technology Disciplines
# Year                                Medicine Agri. Vety.Sc.
# 1993-94                                 53.8   3.8      1.0
# 1994-95                                 53.8   3.8      1.0
# 1995-96                                 53.8   3.8      1.0
# 1996-97                                 53.8   3.8      1.0

# %% [markdown]
# ### 3. Hot Deck Imputation - filling later value

# %%
hot_deck_2 = dataset.fillna(method='bfill')
hot_deck_2.iloc[5:9, 2:5]
# Out:
# Discipline  Science & Technology Disciplines
# Year                                Medicine Agri. Vety.Sc.
# 1993-94                                 80.7  14.7      2.4
# 1994-95                                 80.7  14.7      2.4
# 1995-96                                 80.7  14.7      2.4
# 1996-97                                 80.7  14.7      2.4

# %% [markdown]
# ## Interpolation - Linear Interpolation

# %%
dataset_interpolated = dataset.interpolate()
dataset_interpolated.iloc[5:9, 2:5]
# Out:
# Discipline  Science & Technology Disciplines
# Year                                Medicine  Agri. Vety.Sc.
# 1993-94                                59.18   5.98     1.28
# 1994-95                                64.56   8.16     1.56
# 1995-96                                69.94  10.34     1.84
# 1996-97                                75.32  12.52     2.12

# %% [markdown]
# ## Verification

# %%
original_value = dataset.iloc[7, 1]
dataset.iloc[7, 1] = np.nan

interpolated_value = dataset.interpolate().iloc[7, 1]

print(original_value, interpolated_value)
# Out:
# 26.4 26.25
